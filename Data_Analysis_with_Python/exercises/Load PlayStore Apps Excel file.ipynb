# %% [markdown]
# # Load PlayStore Apps Excel file
#
# Read the `playstore.xlsx` Excel file from the given `data_url` and store it in a `playstore_df` DataFrame.
#
# - When reading in the file, only use the columns `'App', 'Rating', 'Installs', 'Rating', 'Genres', 'Last_Updated'`.
# - Make sure `Last_Updated` is in datetime format, try do this while reading the file into the DataFrame.
#
# After reading the data, filter the records and keep only the top 25 with highest `Rating` (being 5 the highest possible rating value).
#
# > This files originated as a CSV from Kaggle and has been altered for this course, https://www.kaggle.com/lava18/google-play-store-apps

# %%
import pandas as pd

# %%
playstore_df= pd.read_excel('playstore.xlsx', usecols=['App', 'Rating', 'Installs', 'Rating', 'Genres', 'Last_Updated'],parse_dates=['Last_Updated'],index_col='Rating')

playstore_df
# Out:
#                                                       App     Installs  \
# Rating
# 4.1        Photo Editor & Candy Camera & Grid & ScrapBook      10,000+
# 3.9                                   Coloring book moana     500,000+
# 4.7     U Launcher Lite – FREE Live Cool Themes, Hide ...   5,000,000+
# 4.5                                 Sketch - Draw & Paint  50,000,000+
# 4.3                 Pixel Draw - Number Art Coloring Book     100,000+
# ...                                                   ...          ...
# 3.5                              Xero Accounting Software     100,000+
# 4.1               MailChimp - Email, Marketing Automation     500,000+
# 4.6                  Crew - Free Messaging and Scheduling     500,000+
# 4.3                         Asana: organize team projects   1,000,000+
# 4.5                                      Google Analytics   1,000,000+
#
#                            Genres Last_Updated
# Rating
# 4.1                  Art & Design   2018-01-07
# 3.9     Art & Design;Pretend Play   2018-01-15
# 4.7                  Art & Design   2018-08-01
# 4.5                  Art & Design   2018-06-08
# 4.3       Art & Design;Creativity   2018-06-20
# ...                           ...          ...
# 3.5                      Business   2018-07-30
# 4.1                      Business   2018-07-25
# 4.6                      Business   2018-07-20
# 4.3                      Business   2018-07-26
# 4.5                      Business   2018-02-13
#
# [250 rows x 4 columns]

# %%
playstore_top25=playstore_df.sort_values(by='Rating', ascending=False)
playstore_top25.head( n=25)
# Out:
#                                                       App     Installs  \
# Rating
# 4.9                               Tickets + PDA 2018 Exam   1,000,000+
# 4.9                        CDL Practice Test 2018 Edition     100,000+
# 4.9                        ipsy: Makeup, Beauty, and Tips   1,000,000+
# 4.9                 DMV Permit Practice Test 2018 Edition     100,000+
# 4.9     Tickets SDA 2018 and Exam from the State Traff...     100,000+
# 4.9              eBoox new: Reader for fb2 epub zip books      50,000+
# 4.8     Fines of the State Traffic Safety Inspectorate...   5,000,000+
# 4.8                                                PDD-UA     100,000+
# 4.8                            Tickets SDA 2019 + Exam RF     500,000+
# 4.8                                  Prom MakeUp Tutorial      10,000+
# 4.8                        Tiny Scanner Pro: PDF Doc Scan     100,000+
# 4.8                            Job Search by ZipRecruiter   1,000,000+
# 4.8                           ReadEra – free ebook reader   1,000,000+
# 4.8            Free Books - Spirit Fanfiction and Stories   1,000,000+
# 4.8                            Harley Quinn wallpapers HD      10,000+
# 4.7                                       I Creative Idea      10,000+
# 4.7        UNICORN - Color By Number & Pixel Art Coloring     500,000+
# 4.7                        PIP Camera - PIP Collage Maker      10,000+
# 4.7                                           Ulta Beauty   1,000,000+
# 4.7                                 Tie - Always be happy      50,000+
# 4.7                       Natural recipes for your beauty     100,000+
# 4.7                            Hush - Beauty for Everyone     500,000+
# 4.7                         Colorfit - Drawing & Coloring     500,000+
# 4.7     Canva: Poster, banner, card maker & graphic de...  10,000,000+
# 4.7                             NOOK App for NOOK Devices     500,000+
#
#                          Genres Last_Updated
# Rating
# 4.9             Auto & Vehicles   2018-07-15
# 4.9             Auto & Vehicles   2018-07-03
# 4.9                      Beauty   2017-11-09
# 4.9             Auto & Vehicles   2018-07-03
# 4.9             Auto & Vehicles   2018-07-18
# 4.9           Books & Reference   2018-07-17
# 4.8             Auto & Vehicles   2018-08-02
# 4.8             Auto & Vehicles   2018-07-29
# 4.8             Auto & Vehicles   2018-07-27
# 4.8                      Beauty   2018-06-26
# 4.8                    Business   2017-04-11
# 4.8                    Business   2018-07-19
# 4.8           Books & Reference   2018-06-02
# 4.8           Books & Reference   2018-08-01
# 4.8                Art & Design   2018-04-25
# 4.7                Art & Design   2018-04-27
# 4.7     Art & Design;Creativity   2018-08-02
# 4.7                Art & Design   2017-11-29
# 4.7                      Beauty   2018-06-05
# 4.7                      Beauty   2018-06-21
# 4.7                      Beauty   2018-05-15
# 4.7                      Beauty   2018-08-02
# 4.7     Art & Design;Creativity   2017-10-11
# 4.7                Art & Design   2018-07-31
# 4.7           Books & Reference   2018-04-25

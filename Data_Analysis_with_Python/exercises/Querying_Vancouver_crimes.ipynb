# %% [markdown]
# # Querying Vancouver crimes
#
# Using the given sqlite3 connection:
# - Select `TYPE`, `MONTH`, `DAY` and `NEIGHBOURHOOD` from the `van_crimes` table, but only the crime observations from `Stanley Park` or `West End`. Store the information in a `van_crimes_df` DataFrame.
# - Store the count of crimes per `TYPE` in a `crime_types_count` variable.

# %%
# !pip install sqlalchemy

# %%
import sqlite3
import pandas as pd

# %%
conn= sqlite3.connect(   'van_crime_2003 (1).db'           )#connect to the datbase
cur= conn.cursor()#create a cursor

cur.executescript(open('van_crime_2003 (1).sql', 'r').read())#execute the script in the file


van_crimes_df = pd.read_sql('SELECT * FROM van_crimes', conn)# get and transform in a df
# Out:
#                                   TYPE  YEAR  MONTH   DAY  HOUR  MINUTE  \
# 0                   Theft from Vehicle  2003      6  28.0  13.0    30.0
# 1                   Theft from Vehicle  2003     11  17.0  16.0     0.0
# 2                   Theft from Vehicle  2003     12  30.0  14.0     0.0
# 3                     Theft of Vehicle  2003      1  15.0  14.0    45.0
# 4                   Theft from Vehicle  2003     12  28.0  16.0    45.0
# ..                                 ...   ...    ...   ...   ...     ...
# 495  Break and Enter Residential/Other  2003      2  15.0   8.0     0.0
# 496  Break and Enter Residential/Other  2003      6  11.0  15.0    45.0
# 497                   Theft of Vehicle  2003      4   1.0  21.0     0.0
# 498                   Theft of Vehicle  2003      8  29.0  23.0     0.0
# 499                   Theft of Vehicle  2003      2   6.0   9.0    10.0
#
#             HUNDRED_BLOCK              NEIGHBOURHOOD          X           Y
# ...

# %%
query="""SELECT TYPE, MONTH, DAY ,NEIGHBOURHOOD FROM van_crimes where NEIGHBOURHOOD = 'Stanley Park' OR NEIGHBOURHOOD = 'West End' """

location_crime = pd.read_sql(query,conn)

location_crime
# Out:
#                                   TYPE  MONTH   DAY NEIGHBOURHOOD
# 0                   Theft from Vehicle     12  30.0  Stanley Park
# 1                   Theft from Vehicle     12  28.0  Stanley Park
# 2                   Theft from Vehicle     12  12.0  Stanley Park
# 3                   Theft from Vehicle     12  12.0  Stanley Park
# 4                   Theft from Vehicle     11   5.0  Stanley Park
# ..                                 ...    ...   ...           ...
# 123  Break and Enter Residential/Other      1  23.0      West End
# 124  Break and Enter Residential/Other      2   2.0      West End
# 125  Break and Enter Residential/Other      2  12.0      West End
# 126  Break and Enter Residential/Other      2  15.0      West End
# 127  Break and Enter Residential/Other      6  11.0      West End
#
# [128 rows x 4 columns]

# %%
crime_types_count = van_crimes_df.loc[:,'TYPE'].value_counts()
# muestra tabla type y su cuenta
#agrupados type(se agrupan aeso)
#y organiza count
crime_types_count_query=""" SELECT TYPE, COUNT(*) AS count
FROM van_crimes
GROUP BY TYPE
ORDER BY count DESC;   """
crime_types_count_sql=pd.read_sql(crime_types_count_query,conn)

crime_types_count
# Out:
# TYPE
# Theft of Vehicle                                        200
# Theft from Vehicle                                      156
# Break and Enter Residential/Other                        68
# Mischief                                                 58
# Offence Against a Person                                 10
# Vehicle Collision or Pedestrian Struck (with Injury)      8
# Name: count, dtype: int64

# %%
crime_types_count_sql
# Out:
#                                                 TYPE  count
# 0                                   Theft of Vehicle    200
# 1                                 Theft from Vehicle    156
# 2                  Break and Enter Residential/Other     68
# 3                                           Mischief     58
# 4                           Offence Against a Person     10
# 5  Vehicle Collision or Pedestrian Struck (with I...      8

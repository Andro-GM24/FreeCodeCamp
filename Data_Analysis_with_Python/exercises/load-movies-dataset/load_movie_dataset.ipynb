# %%
import pandas as pd

# %%
df = pd.read_csv('movies.csv', on_bad_lines='skip')

df.head()
# Out:
#   Color|James Cameron|723.0|178.0|760505847.0|Avatar |3054.0|USA|PG-13|237  \
# 0  Color|Gore Verbinski|302.0|169.0|309404152.0|P...
# 1  Color|Sam Mendes|602.0|148.0|200074175.0|Spect...
# 2  Color|Christopher Nolan|813.0|164.0|448130642....
# 3  ?|Doug Walker|?|?|?|Star Wars: Episode VII - T...
# 4  Color|Andrew Stanton|462.0|132.0|73058679.0|Jo...
#
#      000  000.0|2009.0|7.9|Action
# 0    0.0  000.0|2007.0|7.1|Action
# 1    0.0  000.0|2015.0|6.8|Action
# 2    0.0  000.0|2012.0|8.5|Action
# 3    NaN                      NaN
# 4  700.0  000.0|2012.0|6.6|Action
